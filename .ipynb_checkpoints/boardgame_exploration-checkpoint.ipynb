# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
## df is original database
df = pd.read_csv('boardgames.csv')
df=df.set_index('title')
df.describe()
# Out:
#          avg_rating   geek_rating    num_rating          rank           year
# count  87716.000000  26951.000000  87716.000000  19736.000000  112662.000000
# mean       6.333456      5.700169    218.827215   9922.746301    2003.042579
# std        1.592310      0.357737   1694.296798   5748.322018      69.907653
# min        1.000000      3.546000      1.000000      1.000000       2.000000
# 25%        5.460000      5.521000      2.000000   4945.750000    1999.000000
# 50%        6.500000      5.565000      9.000000   9901.500000    2011.000000
# 75%        7.420000      5.708000     45.000000  14893.250000    2016.000000
# max       10.000000      8.559000  99275.000000  19924.000000   22014.000000

# %%
df.shape
#df.head()
# Out:
# (112662, 7)

# %%
top10 = df.sort_values('num_rating',ascending=False).head(10)
top10 = top10[['year','avg_rating','num_rating','description']]
top10
# Out:
#                    year  avg_rating  num_rating  \
# title
# Pandemic           2008        7.61     99275.0
# Carcassonne        2000        7.42     99123.0
# Catan              1995        7.16     98881.0
# 7 Wonders          2010        7.76     82343.0
# Dominion           2008        7.62     76594.0
# Ticket to Ride     2004        7.43     69809.0
# Codenames          2015        7.63     65251.0
# Agricola           2007        7.95     62614.0
# Puerto Rico        2002        8.00     62246.0
# Terraforming Mars  2016        8.43     61367.0
#
#                                                          description
# title
# Pandemic           Your team of experts must prevent the world fr...
# Carcassonne        Shape the medieval landscape of France, claimi...
# Catan              Collect and trade resources to build up the is...
# 7 Wonders          Draft cards to develop your ancient civilizati...
# Dominion           Acquire the most valuable lands by building yo...
# Ticket to Ride     Build your railroad across North America to co...
# Codenames          Give your team clever one-word clues to help t...
# Agricola           Build your farmstead by sowing fields and rais...
# Puerto Rico        Ship goods, construct buildings, and choose ro...
# Terraforming Mars  Compete with rival CEOs to make Mars habitable...

# %% [markdown]
# ## df1 cleans for dates

# %%
df.sort_values('year',ascending=False)
df1 = df.loc[df.year<2100]
df1.shape
# Out:
# (112651, 7)

# %%
df1 = df1.loc[df1.year>1800]
df1.sort_values('year').head()
# Out:
#                                       avg_rating description  geek_rating  \
# title
# The Infant's Cabinet of Fishes               NaN         NaN          NaN
# Skittles                                    5.72         NaN         5.51
# The Reward of Merit                          NaN         NaN          NaN
# Grammatical Game in Rhyme: By a Lady         NaN         NaN          NaN
# Wallis's Tour Through Asia                   NaN         NaN          NaN
#
#                                       num_rating     rank  \
# title
# The Infant's Cabinet of Fishes               NaN      NaN
# Skittles                                   102.0  15002.0
# The Reward of Merit                          NaN      NaN
# Grammatical Game in Rhyme: By a Lady         NaN      NaN
# Wallis's Tour Through Asia                   NaN      NaN
#
#                                                                                     url  \
# title
# The Infant's Cabinet of Fishes        https://boardgamegeek.com/boardgame/68596/infa...
# Skittles                              https://boardgamegeek.com/boardgame/3276/skittles
# The Reward of Merit                   https://boardgamegeek.com/boardgame/37017/rewa...
# Grammatical Game in Rhyme: By a Lady  https://boardgamegeek.com/boardgame/62980/gram...
# Wallis's Tour Through Asia            https://boardgamegeek.com/boardgame/62534/wall...
#
#                                       year
# title
# The Infant's Cabinet of Fishes        1801
# Skittles                              1801
# The Reward of Merit                   1801
# Grammatical Game in Rhyme: By a Lady  1802
# Wallis's Tour Through Asia            1802

# %%
plt.hist(df1['year'])
# Out:
# (array([6.6000e+01, 8.1000e+01, 9.7000e+01, 1.8300e+02, 5.9800e+02,
#         7.7600e+02, 1.8230e+03, 6.2760e+03, 1.9846e+04, 8.2664e+04]),
#  array([1801. , 1823.2, 1845.4, 1867.6, 1889.8, 1912. , 1934.2, 1956.4,
#         1978.6, 2000.8, 2023. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(20,6))
plt.hist(df1['num_rating'],bins=20)
# Out:
# (array([8.6834e+04, 3.6600e+02, 1.3400e+02, 6.8000e+01, 3.7000e+01,
#         3.2000e+01, 1.0000e+01, 1.2000e+01, 7.0000e+00, 5.0000e+00,
#         1.0000e+00, 7.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([1.00000e+00, 4.96470e+03, 9.92840e+03, 1.48921e+04, 1.98558e+04,
#         2.48195e+04, 2.97832e+04, 3.47469e+04, 3.97106e+04, 4.46743e+04,
#         4.96380e+04, 5.46017e+04, 5.95654e+04, 6.45291e+04, 6.94928e+04,
#         7.44565e+04, 7.94202e+04, 8.43839e+04, 8.93476e+04, 9.43113e+04,
#         9.92750e+04]),
#  <a list of 20 Patch objects>)

# %%
df1.sort_values('num_rating')
# Out:
#                                            avg_rating  \
# title
# High and Low                                      7.0
# Trade Raiders                                     6.0
# Croc Poissons                                     5.0
# Jenga: Disney Frozen                              3.0
# Glider-Pit Gladiators: Campaign Expansion         7.0
# ...                                               ...
# Contango                                          NaN
# Don't Give Up Your Day Job!                       NaN
# Money, Power, Respect                             NaN
# Nuts! To You                                      NaN
# Earthdefenders                                    NaN
#
#                                                                                  description  \
# title
# High and Low                                                                             NaN
# Trade Raiders                                                                            NaN
# Croc Poissons                                                                            NaN
# Jenga: Disney Frozen                                                                     NaN
# Glider-Pit Gladiators: Campaign Expansion  See you later gladiator? Even more fun with co...
# ...                                                                                      ...
# Contango                                                                                 NaN
# Don't Give Up Your Day Job!                                                              NaN
# Money, Power, Respect                                                                    NaN
# Nuts! To You                                                                             NaN
# Earthdefenders                                                                           NaN
#
#                                            geek_rating  num_rating  rank  \
# title
# High and Low                                       NaN         1.0   NaN
# Trade Raiders                                      NaN         1.0   NaN
# Croc Poissons                                      NaN         1.0   NaN
# Jenga: Disney Frozen                               NaN         1.0   NaN
# Glider-Pit Gladiators: Campaign Expansion          NaN         1.0   NaN
# ...                                                ...         ...   ...
# Contango                                           NaN         NaN   NaN
# Don't Give Up Your Day Job!                        NaN         NaN   NaN
# Money, Power, Respect                              NaN         NaN   NaN
# Nuts! To You                                       NaN         NaN   NaN
# Earthdefenders                                     NaN         NaN   NaN
#
#                                                                                          url  \
# title
# High and Low                               https://boardgamegeek.com/boardgame/83363/high...
# Trade Raiders                              https://boardgamegeek.com/boardgame/131248/tra...
# Croc Poissons                              https://boardgamegeek.com/boardgame/131252/cro...
# Jenga: Disney Frozen                       https://boardgamegeek.com/boardgame/245614/jen...
# Glider-Pit Gladiators: Campaign Expansion  https://boardgamegeek.com/boardgameexpansion/2...
# ...                                                                                      ...
# Contango                                    https://boardgamegeek.com/boardgame/962/contango
# Don't Give Up Your Day Job!                https://boardgamegeek.com/boardgame/1097/dont-...
# Money, Power, Respect                      https://boardgamegeek.com/boardgame/1151/money...
# Nuts! To You                               https://boardgamegeek.com/boardgame/1154/nuts-you
# Earthdefenders                             https://boardgamegeek.com/boardgame/1369/earth...
#
#                                            year
# title
# High and Low                               2010
# Trade Raiders                              1985
# Croc Poissons                              2009
# Jenga: Disney Frozen                       2015
# Glider-Pit Gladiators: Campaign Expansion  1999
# ...                                         ...
# Contango                                   2000
# Don't Give Up Your Day Job!                2000
# Money, Power, Respect                      2000
# Nuts! To You                               1987
# Earthdefenders                             2001
#
# [112410 rows x 7 columns]

# %%
#df2 cleans for all games without ratings
df2 = df1.dropna(subset=['num_rating']) 
df2.sort_values('num_rating',ascending=False).head(10)
# Out:
#                    avg_rating  \
# title
# Pandemic                 7.61
# Carcassonne              7.42
# Catan                    7.16
# 7 Wonders                7.76
# Dominion                 7.62
# Ticket to Ride           7.43
# Codenames                7.63
# Agricola                 7.95
# Puerto Rico              8.00
# Terraforming Mars        8.43
#
#                                                          description  \
# title
# Pandemic           Your team of experts must prevent the world fr...
# Carcassonne        Shape the medieval landscape of France, claimi...
# Catan              Collect and trade resources to build up the is...
# 7 Wonders          Draft cards to develop your ancient civilizati...
# Dominion           Acquire the most valuable lands by building yo...
# Ticket to Ride     Build your railroad across North America to co...
# Codenames          Give your team clever one-word clues to help t...
# Agricola           Build your farmstead by sowing fields and rais...
# Puerto Rico        Ship goods, construct buildings, and choose ro...
# Terraforming Mars  Compete with rival CEOs to make Mars habitable...
#
#                    geek_rating  num_rating   rank  \
# title
# Pandemic                 7.511     99275.0   97.0
# Carcassonne              7.309     99123.0  178.0
# Catan                    6.994     98881.0  385.0
# 7 Wonders                7.656     82343.0   58.0
# Dominion                 7.515     76594.0   96.0
# Ticket to Ride           7.321     69809.0  170.0
# Codenames                7.538     65251.0   89.0
# Agricola                 7.839     62614.0   32.0
# Puerto Rico              7.873     62246.0   27.0
# Terraforming Mars        8.284     61367.0    4.0
#
#                                                                  url  year
# title
# Pandemic           https://boardgamegeek.com/boardgame/30549/pand...  2008
# Carcassonne        https://boardgamegeek.com/boardgame/822/carcas...  2000
# Catan                   https://boardgamegeek.com/boardgame/13/catan  1995
# 7 Wonders          https://boardgamegeek.com/boardgame/68448/7-wo...  2010
# Dominion           https://boardgamegeek.com/boardgame/36218/domi...  2008
# Ticket to Ride     https://boardgamegeek.com/boardgame/9209/ticke...  2004
# Codenames          https://boardgamegeek.com/boardgame/178900/cod...  2015
# Agricola           https://boardgamegeek.com/boardgame/31260/agri...  2007
# Puerto Rico        https://boardgamegeek.com/boardgame/3076/puert...  2002
# Terraforming Mars  https://boardgamegeek.com/boardgame/167791/ter...  2016

# %%
plt.figure(figsize=(12,6))
plt.hist(np.log(df2.num_rating.dropna()),bins=30)
plt.xlabel('log of No. of Ratings')
plt.ylabel('count')
plt.title('Histogram of No. of Ratings', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Histogram of No. of Ratings')

# %%
# df[df.num_rating>10][df.year<1950]['year'].value_counts()
df1[df1.year<1950]
# Out:
#                         avg_rating  \
# title
# Crokinole                     7.88
# Casino                        6.30
# International Checkers        6.52
# Go-Moku                       6.00
# Sheepshead                    8.31
# ...                            ...
# Mahjong                       7.02
# Cribbage                      7.06
# Perudo                        6.91
# Bridge                        7.46
# Chess                         7.11
#
#                                                               description  \
# title
# Crokinole               Flick discs and make trick shots in this tradi...
# Casino                  Classic game for 2 to 4 players where you "fis...
# International Checkers                                                NaN
# Go-Moku                                                               NaN
# Sheepshead                                                            NaN
# ...                                                                   ...
# Mahjong                 Use the Winds, Dragons and suit tiles you draw...
# Cribbage                Sum to 15, peg to 121 and score the crib in th...
# Perudo                  Roll dice, take a chance, and bluff your way t...
# Bridge                  Bid to communicate and to set trump. Then take...
# Chess                   Warring kings send subjects to capture the ene...
#
#                         geek_rating  num_rating    rank  \
# title
# Crokinole                     7.612     11754.0    67.0
# Casino                        5.622       274.0  6309.0
# International Checkers        5.621       233.0  6345.0
# Go-Moku                       5.625       579.0  6239.0
# Sheepshead                    5.628        73.0  6159.0
# ...                             ...         ...     ...
# Mahjong                       6.671      6328.0   746.0
# Cribbage                      6.779      8086.0   605.0
# Perudo                        6.730     12364.0   663.0
# Bridge                        6.726      2877.0   673.0
# Chess                         6.934     27899.0   443.0
#
#                                                                       url  \
# title
# Crokinole               https://boardgamegeek.com/boardgame/521/crokinole
# Casino                   https://boardgamegeek.com/boardgame/18121/casino
# International Checkers  https://boardgamegeek.com/boardgame/26952/inte...
# Go-Moku                 https://boardgamegeek.com/boardgame/11929/go-moku
# Sheepshead              https://boardgamegeek.com/boardgame/154394/she...
# ...                                                                   ...
# Mahjong                  https://boardgamegeek.com/boardgame/2093/mahjong
# Cribbage                https://boardgamegeek.com/boardgame/2398/cribbage
# Perudo                      https://boardgamegeek.com/boardgame/45/perudo
# Bridge                    https://boardgamegeek.com/boardgame/2181/bridge
# Chess                       https://boardgamegeek.com/boardgame/171/chess
#
#                         year
# title
# Crokinole               1876
# Casino                  1800
# International Checkers  1600
# Go-Moku                  700
# Sheepshead              1830
# ...                      ...
# Mahjong                 1850
# Cribbage                1630
# Perudo                  1800
# Bridge                  1908
# Chess                   1475
#
# [1194 rows x 7 columns]

# %%
boardgame_df = df.loc[df.year>1950,:]
boardgame_df = boardgame_df.loc[boardgame_df.year<2100,:]
boardgame_df = boardgame_df.loc[boardgame_df.num_rating>100,:]
boardgame_df
# Out:
#                                          avg_rating  \
# title
# Gloomhaven                                     8.80
# Pandemic Legacy: Season 1                      8.62
# Brass: Birmingham                              8.65
# Terraforming Mars                              8.43
# Twilight Imperium: Fourth Edition              8.69
# ...                                             ...
# Power Grid Deluxe: Europe/North America        8.02
# Lewis & Clark: The Expedition                  7.50
# 1960: The Making of the President              7.61
# Horrified                                      7.85
# Bora Bora                                      7.56
#
#                                                                                description  \
# title
# Gloomhaven                               Vanquish monsters with strategic cardplay. Ful...
# Pandemic Legacy: Season 1                Mutating diseases are spreading around the wor...
# Brass: Birmingham                        Build networks, grow industries, and navigate ...
# Terraforming Mars                        Compete with rival CEOs to make Mars habitable...
# Twilight Imperium: Fourth Edition        Build an intergalactic empire through trade, r...
# ...                                                                                    ...
# Power Grid Deluxe: Europe/North America                                                NaN
# Lewis & Clark: The Expedition            Explorers race from Missouri to Oregon, asking...
# 1960: The Making of the President        Players act as campaign managers in this repla...
# Horrified                                Classic movie monsters terrorize a town! Can y...
# Bora Bora                                Balance difficult choices and seek glory on an...
#
#                                          geek_rating  num_rating   rank  \
# title
# Gloomhaven                                     8.559     39809.0    1.0
# Pandemic Legacy: Season 1                      8.468     40149.0    2.0
# Brass: Birmingham                              8.352     17279.0    3.0
# Terraforming Mars                              8.284     61367.0    4.0
# Twilight Imperium: Fourth Edition              8.238     12641.0    5.0
# ...                                              ...         ...    ...
# Power Grid Deluxe: Europe/North America        7.268      3675.0  196.0
# Lewis & Clark: The Expedition                  7.268     12640.0  197.0
# 1960: The Making of the President              7.263      8420.0  198.0
# Horrified                                      7.262      5426.0  199.0
# Bora Bora                                      7.259      9005.0  200.0
#
#                                                                                        url  \
# title
# Gloomhaven                               https://boardgamegeek.com/boardgame/174430/glo...
# Pandemic Legacy: Season 1                https://boardgamegeek.com/boardgame/161936/pan...
# Brass: Birmingham                        https://boardgamegeek.com/boardgame/224517/bra...
# Terraforming Mars                        https://boardgamegeek.com/boardgame/167791/ter...
# Twilight Imperium: Fourth Edition        https://boardgamegeek.com/boardgame/233078/twi...
# ...                                                                                    ...
# Power Grid Deluxe: Europe/North America  https://boardgamegeek.com/boardgame/155873/pow...
# Lewis & Clark: The Expedition            https://boardgamegeek.com/boardgame/140620/lew...
# 1960: The Making of the President        https://boardgamegeek.com/boardgame/27708/1960...
# Horrified                                https://boardgamegeek.com/boardgame/282524/hor...
# Bora Bora                                https://boardgamegeek.com/boardgame/127060/bor...
#
#                                          year
# title
# Gloomhaven                               2017
# Pandemic Legacy: Season 1                2015
# Brass: Birmingham                        2018
# Terraforming Mars                        2016
# Twilight Imperium: Fourth Edition        2017
# ...                                       ...
# Power Grid Deluxe: Europe/North America  2014
# Lewis & Clark: The Expedition            2013
# 1960: The Making of the President        2007
# Horrified                                2019
# Bora Bora                                2013
#
# [14113 rows x 7 columns]

# %%
boardgame_df[boardgame_df['num_rating']==boardgame_df['num_rating'].max()]
# Out:
#           avg_rating                                        description  \
# title
# Pandemic        7.61  Your team of experts must prevent the world fr...
#
#           geek_rating  num_rating  rank  \
# title
# Pandemic        7.511     99275.0  97.0
#
#                                                         url  year
# title
# Pandemic  https://boardgamegeek.com/boardgame/30549/pand...  2008

# %%
plt.figure(figsize=(20,6))
plt.hist(boardgame_df['year'],bins=70)
plt.xlabel('year')
plt.ylabel('count')
plt.title('Histogram by year', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Histogram by year')

# %%
legacy = df.loc[df.year<1950,:]
legacy = legacy.loc[legacy.num_rating>100]
legacy = legacy[['year','avg_rating','num_rating','description']]
legacy.sort_values('num_rating',ascending=False).head(10) #top 10 legacy games by popularity
# Out:
#             year  avg_rating  num_rating  \
# title
# Chess       1475        7.11     27899.0
# Monopoly    1933        4.37     27843.0
# Scrabble    1948        6.28     26104.0
# Clue        1949        5.67     17145.0
# Stratego    1946        6.09     13550.0
# Perudo      1800        6.91     12364.0
# Crokinole   1876        7.88     11754.0
# Poker       1810        6.71      9103.0
# Battleship  1931        4.63      8294.0
# Pit         1903        6.39      8154.0
#
#                                                   description
# title
# Chess       Warring kings send subjects to capture the ene...
# Monopoly    Buy properties, trade for sets, build houses, ...
# Scrabble    Carefully place your lettered tiles to make hi...
# Clue        Catch the culprit of a crime by identifying wh...
# Stratego    Opposing forces march to capture the flag! Out...
# Perudo      Roll dice, take a chance, and bluff your way t...
# Crokinole   Flick discs and make trick shots in this tradi...
# Poker       You've got to know when to hold 'em; know when...
# Battleship                Detect the enemy fleet and sink it.
# Pit         Trade 1! Trade 2! Trade 3! Trade 4! Will you g...

# %%
len(legacy)
# Out:
# 132

# %%
plt.figure(figsize=(20,6))
plt.scatter(legacy['num_rating'], legacy['avg_rating'])

# %%
plt.figure(figsize=(20,10))
plt.scatter(boardgame_df['year'], boardgame_df['avg_rating'])

# %%
year_df = boardgame_df[['year', 'avg_rating']]
year_df.boxplot(by='year',figsize=(10,12),vert=False)
plt.savefig("year.jpg")

# %%
year_df['year'].hist(bins=70,,figsize=(12,4))

# %%
boardgame_df['num_rating'].mean()
# Out:
# 1257.6124849429605

# %%
##### export url list to be called by selenium
# s = boardgame_df.reset_index()['url']
# s.to_csv('games_url.csv')

# %% [markdown]
# ## Merging details db

# %%
import re
detail_df = pd.read_csv('game_details.csv')
detail_df = detail_df.set_index('title')
detail_df['category'] = [re.findall('\w+',x) for x in detail_df['category']]
detail_df
# Out:
#                                age  complexity  min_player  max_player  \
# title
# Alaska                        12.0        1.44           2           4
# CLUE: World of Harry Potter    9.0        1.75           3           5
# Karnivore Koala               12.0        1.38           2           6
# Arcadia                        8.0        2.00           2           4
# Loch Ness                      8.0        1.52           2           5
# ...                            ...         ...         ...         ...
# I'm the Boss!: The Card Game   9.0        1.75           3           6
# Maloney's Inheritance         12.0        2.00           3           6
# Uncle Chestnut's Table Gype    8.0        2.00           2           4
# Dschamál                       8.0        1.19           3           8
# MixUp                          8.0        1.67           2           2
#
#                               min_time  max_time            category  \
# title
# Alaska                              60        60            [Family]
# CLUE: World of Harry Potter         30        30                  []
# Karnivore Koala                     20        30             [Party]
# Arcadia                             45        60                  []
# Loch Ness                           30        45                  []
# ...                                ...       ...                 ...
# I'm the Boss!: The Card Game        45        45                  []
# Maloney's Inheritance               45        45  [Family, Strategy]
# Uncle Chestnut's Table Gype         30        30          [Abstract]
# Dschamál                            20        20                  []
# MixUp                               20        20          [Abstract]
#
#                                                                     subcategory
# title
# Alaska                                                       ['Transportation']
# CLUE: World of Harry Potter   ['Deduction', 'Fantasy', 'Movies / TV / Radio ...
# Karnivore Koala                       ['Animals', 'Card Game', 'Dice', 'Humor']
# Arcadia                                                           ['Card Game']
# Loch Ness                                             ['Bluffing', 'Deduction']
# ...                                                                         ...
# I'm the Boss!: The Card Game           ['Card Game', 'Economic', 'Negotiation']
# Maloney's Inheritance                                        ['Transportation']
# Uncle Chestnut's Table Gype                       ['Abstract Strategy', 'Dice']
# Dschamál                                    ['Action / Dexterity', 'Real-time']
# MixUp                                                     ['Abstract Strategy']
#
# [13843 rows x 8 columns]

# %%
test = detail_df['category'][1]
type(test)
# Out:
# list

# %%
db = pd.merge(boardgame_df,detail_df,how="inner",on="title")
db.describe()
# Out:
#          avg_rating   geek_rating    num_rating          rank          year  \
# count  14113.000000  14113.000000  14113.000000  11035.000000  14113.000000
# mean       6.777282      5.853870   1301.974492   6842.700227   2008.094523
# std        0.871475      0.442599   4154.009927   5441.358311     11.485627
# min        1.110000      4.295000    101.000000      1.000000   1951.000000
# 25%        6.200000      5.580000    165.000000   2714.500000   2004.000000
# 50%        6.790000      5.691000    310.000000   5441.000000   2012.000000
# 75%        7.410000      5.968000    830.000000   9115.000000   2016.000000
# max        9.530000      8.559000  99275.000000  19919.000000   2021.000000
#
#                 age    complexity    min_player    max_player      min_time  \
# count  13647.000000  13981.000000  14113.000000  14113.000000  14113.000000
# mean      10.737012      2.198984      1.986679      4.396089     69.792532
# std        2.597465      0.795574      0.694849      1.756262    537.332790
# min        2.000000      1.000000      1.000000      1.000000      1.000000
# 25%        8.000000      1.550000      2.000000      4.000000     30.000000
# 50%       10.000000      2.130000      2.000000      4.000000     45.000000
# 75%       12.000000      2.730000      2.000000      6.000000     60.000000
# max       21.000000      5.000000      9.000000      9.000000  60000.000000
#
#            max_time
# count  14113.000000
# mean      95.117764
# std      601.755575
# min        0.000000
# 25%       30.000000
# 50%       60.000000
# 75%       90.000000
# max    60000.000000

# %%
db['avg_time']=(db['min_time']+db['max_time'])/2
db.head()
# Out:
#                                    avg_rating  \
# title
# Gloomhaven                               8.80
# Pandemic Legacy: Season 1                8.62
# Brass: Birmingham                        8.65
# Terraforming Mars                        8.43
# Twilight Imperium: Fourth Edition        8.69
#
#                                                                          description  \
# title
# Gloomhaven                         Vanquish monsters with strategic cardplay. Ful...
# Pandemic Legacy: Season 1          Mutating diseases are spreading around the wor...
# Brass: Birmingham                  Build networks, grow industries, and navigate ...
# Terraforming Mars                  Compete with rival CEOs to make Mars habitable...
# Twilight Imperium: Fourth Edition  Build an intergalactic empire through trade, r...
#
#                                    geek_rating  num_rating  rank  \
# title
# Gloomhaven                               8.559     39809.0   1.0
# Pandemic Legacy: Season 1                8.468     40149.0   2.0
# Brass: Birmingham                        8.352     17279.0   3.0
# Terraforming Mars                        8.284     61367.0   4.0
# Twilight Imperium: Fourth Edition        8.238     12641.0   5.0
#
#                                                                                  url  \
# title
# Gloomhaven                         https://boardgamegeek.com/boardgame/174430/glo...
# Pandemic Legacy: Season 1          https://boardgamegeek.com/boardgame/161936/pan...
# Brass: Birmingham                  https://boardgamegeek.com/boardgame/224517/bra...
# Terraforming Mars                  https://boardgamegeek.com/boardgame/167791/ter...
# Twilight Imperium: Fourth Edition  https://boardgamegeek.com/boardgame/233078/twi...
#
#                                    year   age  complexity  min_player  \
# title
# Gloomhaven                         2017  14.0        3.85           1
# Pandemic Legacy: Season 1          2015  13.0        2.83           2
# Brass: Birmingham                  2018  14.0        3.91           2
# Terraforming Mars                  2016  12.0        3.24           1
# Twilight Imperium: Fourth Edition  2017  14.0        4.22           3
#
#                                    max_player  min_time  max_time  \
# title
# Gloomhaven                                  4        60       120
# Pandemic Legacy: Season 1                   4        60        60
# Brass: Birmingham                           4        60       120
# Terraforming Mars                           5       120       120
# Twilight Imperium: Fourth Edition           6       240       480
#
#                                                category  \
# title
# Gloomhaven                         [Strategy, Thematic]
# Pandemic Legacy: Season 1          [Strategy, Thematic]
# Brass: Birmingham                            [Strategy]
# Terraforming Mars                            [Strategy]
# Twilight Imperium: Fourth Edition  [Strategy, Thematic]
#
#                                                                          subcategory  \
# title
# Gloomhaven                         ['Adventure', 'Exploration', 'Fantasy', 'Fight...
# Pandemic Legacy: Season 1                               ['Environmental', 'Medical']
# Brass: Birmingham                  ['Economic', 'Industry / Manufacturing', 'Tran...
# Terraforming Mars                  ['Economic', 'Environmental', 'Industry / Manu...
# Twilight Imperium: Fourth Edition  ['Civilization', 'Economic', 'Negotiation', 'P...
#
#                                    avg_time
# title
# Gloomhaven                             90.0
# Pandemic Legacy: Season 1              60.0
# Brass: Birmingham                      90.0
# Terraforming Mars                     120.0
# Twilight Imperium: Fourth Edition     360.0

# %%
plt.figure(figsize=(12,6))
plt.scatter(db['age'], db['complexity'])
plt.ylabel('complexity')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
plt.figure(figsize=(12,6))
db.plot(kind='scatter',x='age', y='complexity')
plt.xlabel('age')
plt.ylabel('complexity')
# Out:
# Text(0, 0.5, 'complexity')

# %%
db_category = db[['avg_rating','num_rating','year','age','complexity','min_player','max_player','avg_time','category']]
db_category = db_category[db_category['category'].map(lambda c: len(c)) > 0]
db_category = db_category.reset_index()
db_category
# Out:
#                                         title  avg_rating  num_rating  year  \
# 0                                  Gloomhaven        8.80     39809.0  2017
# 1                   Pandemic Legacy: Season 1        8.62     40149.0  2015
# 2                           Brass: Birmingham        8.65     17279.0  2018
# 3                           Terraforming Mars        8.43     61367.0  2016
# 4           Twilight Imperium: Fourth Edition        8.69     12641.0  2017
# ...                                       ...         ...         ...   ...
# 8239  Power Grid Deluxe: Europe/North America        8.02      3675.0  2014
# 8240            Lewis & Clark: The Expedition        7.50     12640.0  2013
# 8241        1960: The Making of the President        7.61      8420.0  2007
# 8242                                Horrified        7.85      5426.0  2019
# 8243                                Bora Bora        7.56      9005.0  2013
#
#        age  complexity  min_player  max_player  avg_time              category
# 0     14.0        3.85           1           4      90.0  [Strategy, Thematic]
# 1     13.0        2.83           2           4      60.0  [Strategy, Thematic]
# 2     14.0        3.91           2           4      90.0            [Strategy]
# 3     12.0        3.24           1           5     120.0            [Strategy]
# 4     14.0        4.22           3           6     360.0  [Strategy, Thematic]
# ...    ...         ...         ...         ...       ...                   ...
# 8239  12.0        3.20           2           6     120.0            [Strategy]
# 8240  14.0        3.34           1           5     120.0            [Strategy]
# 8241  12.0        3.21           2           2     105.0            [Strategy]
# 8242  10.0        2.04           1           5      60.0    [Family, Thematic]
# 8243  12.0        3.74           2           4      90.0            [Strategy]
#
# [8244 rows x 10 columns]

# %%
index=0
list_ = []
for item in db_category.category:
    list_.extend(map(lambda x: [index, x], item))
    index += 1
categories = pd.DataFrame(list_, columns=['index', 'category'])
categories
# Out:
#        index  category
# 0          0  Strategy
# 1          0  Thematic
# 2          1  Strategy
# 3          1  Thematic
# 4          2  Strategy
# ...      ...       ...
# 10252   8240  Strategy
# 10253   8241  Strategy
# 10254   8242    Family
# 10255   8242  Thematic
# 10256   8243  Strategy
#
# [10257 rows x 2 columns]

# %%
db_category = pd.merge(db_category.drop('category', axis=1), categories, how='outer', left_index=True, right_on='index').set_index('title')
db_category = db_category[db_category.category != "s"]
db_category = db_category.drop('index', 1)
db_category
# Out:
#                                    avg_rating  num_rating  year   age  \
# title
# Gloomhaven                               8.80     39809.0  2017  14.0
# Gloomhaven                               8.80     39809.0  2017  14.0
# Pandemic Legacy: Season 1                8.62     40149.0  2015  13.0
# Pandemic Legacy: Season 1                8.62     40149.0  2015  13.0
# Brass: Birmingham                        8.65     17279.0  2018  14.0
# ...                                       ...         ...   ...   ...
# Lewis & Clark: The Expedition            7.50     12640.0  2013  14.0
# 1960: The Making of the President        7.61      8420.0  2007  12.0
# Horrified                                7.85      5426.0  2019  10.0
# Horrified                                7.85      5426.0  2019  10.0
# Bora Bora                                7.56      9005.0  2013  12.0
#
#                                    complexity  min_player  max_player  \
# title
# Gloomhaven                               3.85           1           4
# Gloomhaven                               3.85           1           4
# Pandemic Legacy: Season 1                2.83           2           4
# Pandemic Legacy: Season 1                2.83           2           4
# Brass: Birmingham                        3.91           2           4
# ...                                       ...         ...         ...
# Lewis & Clark: The Expedition            3.34           1           5
# 1960: The Making of the President        3.21           2           2
# Horrified                                2.04           1           5
# Horrified                                2.04           1           5
# Bora Bora                                3.74           2           4
#
#                                    avg_time  category
# title
# Gloomhaven                             90.0  Strategy
# Gloomhaven                             90.0  Thematic
# Pandemic Legacy: Season 1              60.0  Strategy
# Pandemic Legacy: Season 1              60.0  Thematic
# Brass: Birmingham                      90.0  Strategy
# ...                                     ...       ...
# Lewis & Clark: The Expedition         120.0  Strategy
# 1960: The Making of the President     105.0  Strategy
# Horrified                              60.0    Family
# Horrified                              60.0  Thematic
# Bora Bora                              90.0  Strategy
#
# [9812 rows x 9 columns]

# %%
category_df = db_category[['category', 'complexity']]
category_df.boxplot(by='category', column='complexity',figsize = (12,6))
plt.savefig("complexity.jpg")

# %%
time_category_df = db_category[['category', 'avg_time']]
time_category_df.boxplot(by='category', column='avg_time',figsize = (12,6))

# %%
time_category_df1 = time_category_df[time_category_df.category != "Wargames"]
time_category_df1.boxplot(by='category', column='avg_time',figsize = (12,6))

# %%
plt.figure(figsize=(20,6))
plt.hist(db['complexity'],bins=70)
plt.xlabel('complexity')
plt.ylabel('count')
plt.title('Histogram of complexity', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Histogram of complexity')

# %%
db1 = db[['avg_rating','num_rating','year','age','complexity','avg_time']]
db1.corr()
# Out:
#             avg_rating  num_rating      year       age  complexity  avg_time
# avg_rating    1.000000    0.141405  0.402764  0.380700    0.572425  0.045065
# num_rating    0.141405    1.000000  0.008710  0.021827    0.053969 -0.007022
# year          0.402764    0.008710  1.000000  0.127298    0.033859 -0.054602
# age           0.380700    0.021827  0.127298  1.000000    0.524516  0.063051
# complexity    0.572425    0.053969  0.033859  0.524516    1.000000  0.137263
# avg_time      0.045065   -0.007022 -0.054602  0.063051    0.137263  1.000000

# %%
import seaborn as sns
sns.heatmap(db1.corr(),annot=True)

# %%
sns.jointplot(db['year'], db['complexity'],kind="hex")

# %%
sns.jointplot(db['avg_time'], db['complexity'])

# %%
db[db.min_time == db.min_time.max()]
# Out:
#                                                     avg_rating  \
# title
# The Campaign for North Africa: The Desert War 1...        6.06
#
#                                                                                           description  \
# title
# The Campaign for North Africa: The Desert War 1...  A meticulously detailed war simulation that ta...
#
#                                                     geek_rating  num_rating  \
# title
# The Campaign for North Africa: The Desert War 1...         5.52       146.0
#
#                                                        rank  \
# title
# The Campaign for North Africa: The Desert War 1...  13571.0
#
#                                                                                                   url  \
# title
# The Campaign for North Africa: The Desert War 1...  https://boardgamegeek.com/boardgame/4815/campa...
#
#                                                     year   age  complexity  \
# title
# The Campaign for North Africa: The Desert War 1...  1979  14.0        4.68
#
#                                                     min_player  max_player  \
# title
# The Campaign for North Africa: The Desert War 1...           8           1
#
#                                                     min_time  max_time  \
# title
# The Campaign for North Africa: The Desert War 1...     60000     60000
#
#                                                       category  \
# title
# The Campaign for North Africa: The Desert War 1...  [Wargames]
#
#                                                                     subcategory  \
# title
# The Campaign for North Africa: The Desert War 1...  ['Wargame', 'World War II']
#
#                                                     avg_time
# title
# The Campaign for North Africa: The Desert War 1...   60000.0

# %%
db2 = db[db.avg_time < 8000]
sns.jointplot(db2['avg_time'], db2['complexity'])

# %%
db_category_noWar = db_category[db_category.category != 'Wargames']
db_category_noWar.head()
# Out:
#                            avg_rating  num_rating  year   age  complexity  \
# title
# Gloomhaven                       8.80     39809.0  2017  14.0        3.85
# Gloomhaven                       8.80     39809.0  2017  14.0        3.85
# Pandemic Legacy: Season 1        8.62     40149.0  2015  13.0        2.83
# Pandemic Legacy: Season 1        8.62     40149.0  2015  13.0        2.83
# Brass: Birmingham                8.65     17279.0  2018  14.0        3.91
#
#                            min_player  max_player  avg_time  category
# title
# Gloomhaven                          1           4      90.0  Strategy
# Gloomhaven                          1           4      90.0  Thematic
# Pandemic Legacy: Season 1           2           4      60.0  Strategy
# Pandemic Legacy: Season 1           2           4      60.0  Thematic
# Brass: Birmingham                   2           4      90.0  Strategy

# %%
db_category_War = db_category[db_category.category == 'Wargames']
db_category_War.describe()
# Out:
#         avg_rating    num_rating         year          age   complexity  \
# count  1737.000000   1737.000000  1737.000000  1553.000000  1737.000000
# mean      7.071387    618.639609  1998.932067    11.987122     2.946609
# std       0.789249   1877.720120    14.462250     1.342635     0.690312
# min       3.230000    101.000000  1954.000000     7.000000     1.070000
# 25%       6.510000    143.000000  1987.000000    12.000000     2.450000
# 50%       7.090000    224.000000  2003.000000    12.000000     2.870000
# 75%       7.670000    468.000000  2011.000000    12.000000     3.400000
# max       9.090000  39967.000000  2020.000000    18.000000     5.000000
#
#         min_player   max_player      avg_time
# count  1737.000000  1737.000000   1737.000000
# mean      1.818077     3.109960    271.770581
# std       0.501445     1.813289   1566.464909
# min       1.000000     1.000000     10.000000
# 25%       2.000000     2.000000     82.500000
# 50%       2.000000     2.000000    120.000000
# 75%       2.000000     4.000000    240.000000
# max       8.000000     9.000000  60000.000000

# %%
db_category_noWar.plot(kind='scatter',x='complexity', y='avg_time')
